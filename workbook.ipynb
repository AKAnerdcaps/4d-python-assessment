# %% [markdown]
# ## Setup

# %%
import pandas as pd
import logging 
import sys
import os
sys.path.insert(0,'./src')


from src.utils.logger import sys_logger

os.makedirs("./final_data", exist_ok=True)

# %% [markdown]
# ## Landing Zone to Staging

# %%
from src.utils.splitter import split_files

split_files()
# Out:
# [splitter.py:9]                 Files in landing zone: ['products_20241011.json', 'customer_20241009.csv', 'products_20241010.json', 'sales_20241010.txt', 'sales_20241011.txt', 'sales_20241013.txt', 'sales_20241012.txt', 'sales_20241016.txt', 'sales_20241015.txt', 'products_20241016.json', 'sales_20241014.txt', 'products_20241015.json', 'sales_20241009.txt', 'products_20241014.json', 'products_20241009.json', 'customer_20241016.csv', 'customer_20241015.csv', 'products_20241013.json', 'customer_20241014.csv', 'customer_20241010.csv', 'products_20241012.json', 'customer_20241011.csv', 'customer_20241013.csv', 'customer_20241012.csv']
# [splitter.py:14]                products_20241011.json matched with product
# [splitter.py:17]                products_20241011.json moved to ./data/products/
# [splitter.py:14]                customer_20241009.csv matched with customer
# [splitter.py:17]                customer_20241009.csv moved to ./data/customer/
# [splitter.py:14]                products_20241010.json matched with product
# [splitter.py:17]                products_20241010.json moved to ./data/products/
# [splitter.py:14]                sales_20241010.txt matched with sales
# [splitter.py:17]                sales_20241010.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241011.txt matched with sales
# [splitter.py:17]                sales_20241011.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241013.txt matched with sales
# [splitter.py:17]                sales_20241013.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241012.txt matched with sales
# [splitter.py:17]                sales_20241012.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241016.txt matched with sales
# [splitter.py:17]                sales_20241016.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241015.txt matched with sales
# [splitter.py:17]                sales_20241015.txt moved to ./data/sales/
# [splitter.py:14]                products_20241016.json matched with product
# [splitter.py:17]                products_20241016.json moved to ./data/products/
# [splitter.py:14]                sales_20241014.txt matched with sales
# [splitter.py:17]                sales_20241014.txt moved to ./data/sales/
# [splitter.py:14]                products_20241015.json matched with product
# [splitter.py:17]                products_20241015.json moved to ./data/products/
# [splitter.py:14]                sales_20241009.txt matched with sales
# [splitter.py:17]                sales_20241009.txt moved to ./data/sales/
# [splitter.py:14]                products_20241014.json matched with product
# [splitter.py:17]                products_20241014.json moved to ./data/products/
# [splitter.py:14]                products_20241009.json matched with product
# [splitter.py:17]                products_20241009.json moved to ./data/products/
# [splitter.py:14]                customer_20241016.csv matched with customer
# [splitter.py:17]                customer_20241016.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241015.csv matched with customer
# [splitter.py:17]                customer_20241015.csv moved to ./data/customer/
# [splitter.py:14]                products_20241013.json matched with product
# [splitter.py:17]                products_20241013.json moved to ./data/products/
# [splitter.py:14]                customer_20241014.csv matched with customer
# [splitter.py:17]                customer_20241014.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241010.csv matched with customer
# [splitter.py:17]                customer_20241010.csv moved to ./data/customer/
# [splitter.py:14]                products_20241012.json matched with product
# [splitter.py:17]                products_20241012.json moved to ./data/products/
# [splitter.py:14]                customer_20241011.csv matched with customer
# [splitter.py:17]                customer_20241011.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241013.csv matched with customer
# [splitter.py:17]                customer_20241013.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241012.csv matched with customer
# [splitter.py:17]                customer_20241012.csv moved to ./data/customer/

# %% [markdown]
# ## Staging to Tables

# %%
from src.utils.ingestion import run_ingestion

run_ingestion()
# Out:
# [watermark.py:8]                Reading watermark table from ./watermark.parquet
# [watermark.py:12]               Watermark table not found at ./watermark.parquet. Creating new table
# [watermark.py:14]               Watermark table has 0 rows
# [ingestion.py:12]               Loading customer data
# [watermark.py:18]               Getting last run date for customer
# [watermark.py:21]               No previous runs found for customer
# [files.py:10]                   Getting files to process from ./data/customer/
# [files.py:14]                   Found 8 files to process
# [ingestion.py:19]               Processing customer_20241009.csv
# [files.py:30]                   Reading csv file from ./data/customer/customer_20241009.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:59]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:38]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:64]                   File not found at ./final_data/customer.parquet. Creating new file
# [files.py:66]                   customer file has 0 rows
# [dataframes.py:143]             Found 0 error records for customer
# [files.py:22]                   Getting error filename for customer
# [dataframes.py:49]              Processing file with 5000 records.
# [dataframes.py:82]              Detected 0 old records and 5000 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:26]                   Saving file with 5000 rows to ./final_data/customer.parquet
# [dataframes.py:166]             Processed 5000 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 5000, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:02.018748'), 'file_date': Timestamp('2024-10-09 00:00:00'), 'file_id': '845ead95-d610-412c-b924-657e1085b4ea', 'file_name': 'customer_20241009.csv'}
# [watermark.py:40]               Watermark table now has 1 rows
# [files.py:26]                   Saving file with 1 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241009.csv
# [ingestion.py:19]               Processing customer_20241010.csv
# [files.py:30]                   Reading csv file from ./data/customer/customer_20241010.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:59]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:38]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:66]                   customer file has 5000 rows
# [dataframes.py:143]             Found 0 error records for customer
# [files.py:22]                   Getting error filename for customer
# [dataframes.py:49]              Processing file with 5280 records.
# [dataframes.py:82]              Detected 802 old records and 1082 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:26]                   Saving file with 6082 rows to ./final_data/customer.parquet
# [dataframes.py:166]             Processed 5280 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 5280, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:02.265586'), 'file_date': Timestamp('2024-10-10 00:00:00'), 'file_id': 'af070e90-28e2-4afe-85fe-f2a1389b4abf', 'file_name': 'customer_20241010.csv'}
# [watermark.py:40]               Watermark table now has 2 rows
# [files.py:26]                   Saving file with 2 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241010.csv
# [ingestion.py:19]               Processing customer_20241011.csv
# [files.py:30]                   Reading csv file from ./data/customer/customer_20241011.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:59]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:38]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:66]                   customer file has 6082 rows
# [dataframes.py:143]             Found 0 error records for customer
# [files.py:22]                   Getting error filename for customer
# [dataframes.py:49]              Processing file with 5576 records.
# [dataframes.py:82]              Detected 819 old records and 1115 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:26]                   Saving file with 7197 rows to ./final_data/customer.parquet
# [dataframes.py:166]             Processed 5576 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 5576, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:02.514882'), 'file_date': Timestamp('2024-10-11 00:00:00'), 'file_id': 'f357cbc5-dce9-4a21-aae0-7096167c7731', 'file_name': 'customer_20241011.csv'}
# [watermark.py:40]               Watermark table now has 3 rows
# [files.py:26]                   Saving file with 3 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241011.csv
# [ingestion.py:19]               Processing customer_20241012.csv
# [files.py:30]                   Reading csv file from ./data/customer/customer_20241012.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:59]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:38]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:66]                   customer file has 7197 rows
# [dataframes.py:143]             Found 0 error records for customer
# [files.py:22]                   Getting error filename for customer
# [dataframes.py:49]              Processing file with 5888 records.
# [dataframes.py:82]              Detected 884 old records and 1196 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:26]                   Saving file with 8393 rows to ./final_data/customer.parquet
# [dataframes.py:166]             Processed 5888 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 5888, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:02.781068'), 'file_date': Timestamp('2024-10-12 00:00:00'), 'file_id': '787d34c5-5b8a-4b68-a5e8-a12b25b8b7ac', 'file_name': 'customer_20241012.csv'}
# [watermark.py:40]               Watermark table now has 4 rows
# [files.py:26]                   Saving file with 4 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241012.csv
# [ingestion.py:19]               Processing customer_20241013.csv
# [files.py:30]                   Reading csv file from ./data/customer/customer_20241013.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:59]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:38]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:66]                   customer file has 8393 rows
# [dataframes.py:143]             Found 0 error records for customer
# [files.py:22]                   Getting error filename for customer
# [dataframes.py:49]              Processing file with 6217 records.
# [dataframes.py:82]              Detected 917 old records and 1246 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:26]                   Saving file with 9639 rows to ./final_data/customer.parquet
# [dataframes.py:166]             Processed 6217 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 6217, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:03.101290'), 'file_date': Timestamp('2024-10-13 00:00:00'), 'file_id': 'd1b19f8d-2b48-46c2-8eb6-755eaeb1cef8', 'file_name': 'customer_20241013.csv'}
# [watermark.py:40]               Watermark table now has 5 rows
# [files.py:26]                   Saving file with 5 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241013.csv
# [ingestion.py:19]               Processing customer_20241014.csv
# [files.py:30]                   Reading csv file from ./data/customer/customer_20241014.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:59]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:38]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:66]                   customer file has 9639 rows
# [dataframes.py:143]             Found 0 error records for customer
# [files.py:22]                   Getting error filename for customer
# [dataframes.py:49]              Processing file with 6565 records.
# [dataframes.py:82]              Detected 974 old records and 1322 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:26]                   Saving file with 10961 rows to ./final_data/customer.parquet
# [dataframes.py:166]             Processed 6565 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 6565, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:03.393508'), 'file_date': Timestamp('2024-10-14 00:00:00'), 'file_id': 'c10d832f-6409-49af-af1b-58b2d1e84b9b', 'file_name': 'customer_20241014.csv'}
# [watermark.py:40]               Watermark table now has 6 rows
# [files.py:26]                   Saving file with 6 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241014.csv
# [ingestion.py:19]               Processing customer_20241015.csv
# [files.py:30]                   Reading csv file from ./data/customer/customer_20241015.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:59]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:38]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:66]                   customer file has 10961 rows
# [dataframes.py:143]             Found 0 error records for customer
# [files.py:22]                   Getting error filename for customer
# [dataframes.py:49]              Processing file with 6933 records.
# [dataframes.py:82]              Detected 1041 old records and 1409 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:26]                   Saving file with 12370 rows to ./final_data/customer.parquet
# [dataframes.py:166]             Processed 6933 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 6933, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:03.712183'), 'file_date': Timestamp('2024-10-15 00:00:00'), 'file_id': '7bab80f9-7264-40c5-9f96-de33d014e75b', 'file_name': 'customer_20241015.csv'}
# [watermark.py:40]               Watermark table now has 7 rows
# [files.py:26]                   Saving file with 7 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241015.csv
# [ingestion.py:19]               Processing customer_20241016.csv
# [files.py:30]                   Reading csv file from ./data/customer/customer_20241016.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:59]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:38]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:66]                   customer file has 12370 rows
# [dataframes.py:143]             Found 1 error records for customer
# [files.py:22]                   Getting error filename for customer
# [dataframes.py:49]              Processing file with 7320 records.
# [dataframes.py:82]              Detected 1062 old records and 1449 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:26]                   Saving file with 13819 rows to ./final_data/customer.parquet
# [dataframes.py:166]             Processed 7320 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 7320, 'error_rows': 1, 'process_time': Timestamp('2024-10-21 21:43:04.125996'), 'file_date': Timestamp('2024-10-16 00:00:00'), 'file_id': '0804e89f-db79-49dc-a904-a0801613fef4', 'file_name': 'customer_20241016.csv'}
# [watermark.py:40]               Watermark table now has 8 rows
# [files.py:26]                   Saving file with 8 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241016.csv
# [ingestion.py:12]               Loading sales data
# [watermark.py:18]               Getting last run date for sales
# [watermark.py:21]               No previous runs found for sales
# [files.py:10]                   Getting files to process from ./data/sales/
# [files.py:14]                   Found 8 files to process
# [ingestion.py:19]               Processing sales_20241009.txt
# [files.py:30]                   Reading csv file from ./data/sales/sales_20241009.txt with kwargs {'sep': '~', 'names': ['sale_id', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:59]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:38]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:64]                   File not found at ./final_data/sales.parquet. Creating new file
# [files.py:66]                   sales file has 0 rows
# [dataframes.py:143]             Found 0 error records for sales
# [files.py:22]                   Getting error filename for sales
# [dataframes.py:49]              Processing file with 7960 records.
# [dataframes.py:92]              No existing records found. Returning new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:26]                   Saving file with 7960 rows to ./final_data/sales.parquet
# [dataframes.py:166]             Processed 7960 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 7960, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:04.377239'), 'file_date': Timestamp('2024-10-09 00:00:00'), 'file_id': '86d80f7b-cdb3-495e-9fbc-82aa5868ebcc', 'file_name': 'sales_20241009.txt'}
# [watermark.py:40]               Watermark table now has 9 rows
# [files.py:26]                   Saving file with 9 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241009.txt
# [ingestion.py:19]               Processing sales_20241010.txt
# [files.py:30]                   Reading csv file from ./data/sales/sales_20241010.txt with kwargs {'sep': '~', 'names': ['sale_id', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:59]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:38]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:66]                   sales file has 7960 rows
# [dataframes.py:143]             Found 0 error records for sales
# [files.py:22]                   Getting error filename for sales
# [dataframes.py:49]              Processing file with 8196 records.
# [dataframes.py:112]             Detected 0 changes and 8196 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:26]                   Saving file with 16156 rows to ./final_data/sales.parquet
# [dataframes.py:166]             Processed 8196 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 8196, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:04.642517'), 'file_date': Timestamp('2024-10-10 00:00:00'), 'file_id': '994d7d22-1f73-408f-b58c-79d33b580566', 'file_name': 'sales_20241010.txt'}
# [watermark.py:40]               Watermark table now has 10 rows
# [files.py:26]                   Saving file with 10 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241010.txt
# [ingestion.py:19]               Processing sales_20241011.txt
# [files.py:30]                   Reading csv file from ./data/sales/sales_20241011.txt with kwargs {'sep': '~', 'names': ['sale_id', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:59]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:38]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:66]                   sales file has 16156 rows
# [dataframes.py:143]             Found 0 error records for sales
# [files.py:22]                   Getting error filename for sales
# [dataframes.py:49]              Processing file with 8424 records.
# [dataframes.py:112]             Detected 0 changes and 8424 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:26]                   Saving file with 24580 rows to ./final_data/sales.parquet
# [dataframes.py:166]             Processed 8424 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 8424, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:04.962046'), 'file_date': Timestamp('2024-10-11 00:00:00'), 'file_id': 'a9b95158-941e-44f5-b4c9-4262b80d95cd', 'file_name': 'sales_20241011.txt'}
# [watermark.py:40]               Watermark table now has 11 rows
# [files.py:26]                   Saving file with 11 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241011.txt
# [ingestion.py:19]               Processing sales_20241012.txt
# [files.py:30]                   Reading csv file from ./data/sales/sales_20241012.txt with kwargs {'sep': '~', 'names': ['sale_id', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:59]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:38]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:66]                   sales file has 24580 rows
# [dataframes.py:143]             Found 0 error records for sales
# [files.py:22]                   Getting error filename for sales
# [dataframes.py:49]              Processing file with 8983 records.
# [dataframes.py:112]             Detected 0 changes and 8983 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:26]                   Saving file with 33563 rows to ./final_data/sales.parquet
# [dataframes.py:166]             Processed 8983 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 8983, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:05.250973'), 'file_date': Timestamp('2024-10-12 00:00:00'), 'file_id': '50550dc2-2755-46ba-af50-3a9392babb61', 'file_name': 'sales_20241012.txt'}
# [watermark.py:40]               Watermark table now has 12 rows
# [files.py:26]                   Saving file with 12 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241012.txt
# [ingestion.py:19]               Processing sales_20241013.txt
# [files.py:30]                   Reading csv file from ./data/sales/sales_20241013.txt with kwargs {'sep': '~', 'names': ['sale_id', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:59]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:38]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:66]                   sales file has 33563 rows
# [dataframes.py:143]             Found 0 error records for sales
# [files.py:22]                   Getting error filename for sales
# [dataframes.py:49]              Processing file with 9573 records.
# [dataframes.py:112]             Detected 0 changes and 9573 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:26]                   Saving file with 43136 rows to ./final_data/sales.parquet
# [dataframes.py:166]             Processed 9573 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 9573, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:05.600762'), 'file_date': Timestamp('2024-10-13 00:00:00'), 'file_id': '25456ab5-bdf3-4dea-a955-7166787d414a', 'file_name': 'sales_20241013.txt'}
# [watermark.py:40]               Watermark table now has 13 rows
# [files.py:26]                   Saving file with 13 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241013.txt
# [ingestion.py:19]               Processing sales_20241014.txt
# [files.py:30]                   Reading csv file from ./data/sales/sales_20241014.txt with kwargs {'sep': '~', 'names': ['sale_id', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:59]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:38]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:66]                   sales file has 43136 rows
# [dataframes.py:143]             Found 0 error records for sales
# [files.py:22]                   Getting error filename for sales
# [dataframes.py:49]              Processing file with 9985 records.
# [dataframes.py:112]             Detected 0 changes and 9985 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:26]                   Saving file with 53121 rows to ./final_data/sales.parquet
# [dataframes.py:166]             Processed 9985 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 9985, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:05.928678'), 'file_date': Timestamp('2024-10-14 00:00:00'), 'file_id': '7e094cc7-48df-4c72-95c9-fab078c5eecc', 'file_name': 'sales_20241014.txt'}
# [watermark.py:40]               Watermark table now has 14 rows
# [files.py:26]                   Saving file with 14 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241014.txt
# [ingestion.py:19]               Processing sales_20241015.txt
# [files.py:30]                   Reading csv file from ./data/sales/sales_20241015.txt with kwargs {'sep': '~', 'names': ['sale_id', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:59]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:38]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:66]                   sales file has 53121 rows
# [dataframes.py:143]             Found 0 error records for sales
# [files.py:22]                   Getting error filename for sales
# [dataframes.py:49]              Processing file with 10652 records.
# [dataframes.py:112]             Detected 0 changes and 10652 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:26]                   Saving file with 63773 rows to ./final_data/sales.parquet
# [dataframes.py:166]             Processed 10652 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 10652, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:06.341299'), 'file_date': Timestamp('2024-10-15 00:00:00'), 'file_id': 'd5877b35-1338-4584-9009-812a8d9ea282', 'file_name': 'sales_20241015.txt'}
# [watermark.py:40]               Watermark table now has 15 rows
# [files.py:26]                   Saving file with 15 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241015.txt
# [ingestion.py:19]               Processing sales_20241016.txt
# [files.py:30]                   Reading csv file from ./data/sales/sales_20241016.txt with kwargs {'sep': '~', 'names': ['sale_id', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:59]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:38]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:66]                   sales file has 63773 rows
# [dataframes.py:143]             Found 11395 error records for sales
# [files.py:22]                   Getting error filename for sales
# [dataframes.py:166]             Processed 0 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 0, 'error_rows': 11395, 'process_time': Timestamp('2024-10-21 21:43:06.683625'), 'file_date': Timestamp('2024-10-16 00:00:00'), 'file_id': '5e71c3c5-d7f7-4b3b-9205-5d319e3e9761', 'file_name': 'sales_20241016.txt'}
# [watermark.py:40]               Watermark table now has 16 rows
# [files.py:26]                   Saving file with 16 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241016.txt
# [ingestion.py:12]               Loading product data
# [watermark.py:18]               Getting last run date for product
# [watermark.py:21]               No previous runs found for product
# [files.py:10]                   Getting files to process from ./data/products/
# [files.py:14]                   Found 8 files to process
# [ingestion.py:19]               Processing products_20241009.json
# [files.py:42]                   Reading json file from ./data/products/products_20241009.json with kwargs {}
# [dataframes.py:134]             Processing data for product
# [files.py:59]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:38]                   Reading parquet file from ./final_data/product.parquet
# [files.py:64]                   File not found at ./final_data/product.parquet. Creating new file
# [files.py:66]                   product file has 0 rows
# [dataframes.py:143]             Found 0 error records for product
# [files.py:22]                   Getting error filename for product
# [dataframes.py:49]              Processing file with 5 records.
# [dataframes.py:82]              Detected 0 old records and 5 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:26]                   Saving file with 5 rows to ./final_data/product.parquet
# [dataframes.py:166]             Processed 5 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 5, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:06.707293'), 'file_date': Timestamp('2024-10-09 00:00:00'), 'file_id': '25cc5cec-3727-4964-91f1-deb2bfeef4c4', 'file_name': 'products_20241009.json'}
# [watermark.py:40]               Watermark table now has 17 rows
# [files.py:26]                   Saving file with 17 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241009.json
# [ingestion.py:19]               Processing products_20241010.json
# [files.py:42]                   Reading json file from ./data/products/products_20241010.json with kwargs {}
# [dataframes.py:134]             Processing data for product
# [files.py:59]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:38]                   Reading parquet file from ./final_data/product.parquet
# [files.py:66]                   product file has 5 rows
# [dataframes.py:143]             Found 0 error records for product
# [files.py:22]                   Getting error filename for product
# [dataframes.py:49]              Processing file with 6 records.
# [dataframes.py:82]              Detected 5 old records and 6 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:26]                   Saving file with 11 rows to ./final_data/product.parquet
# [dataframes.py:166]             Processed 6 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 6, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:06.729906'), 'file_date': Timestamp('2024-10-10 00:00:00'), 'file_id': '00633007-d14f-4c31-aa21-721cdbf42158', 'file_name': 'products_20241010.json'}
# [watermark.py:40]               Watermark table now has 18 rows
# [files.py:26]                   Saving file with 18 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241010.json
# [ingestion.py:19]               Processing products_20241011.json
# [files.py:42]                   Reading json file from ./data/products/products_20241011.json with kwargs {}
# [dataframes.py:134]             Processing data for product
# [files.py:59]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:38]                   Reading parquet file from ./final_data/product.parquet
# [files.py:66]                   product file has 11 rows
# [dataframes.py:143]             Found 0 error records for product
# [files.py:22]                   Getting error filename for product
# [dataframes.py:49]              Processing file with 7 records.
# [dataframes.py:82]              Detected 6 old records and 7 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:26]                   Saving file with 18 rows to ./final_data/product.parquet
# [dataframes.py:166]             Processed 7 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 7, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:06.805277'), 'file_date': Timestamp('2024-10-11 00:00:00'), 'file_id': 'bbf8ae13-3b66-4602-af46-476a8907b263', 'file_name': 'products_20241011.json'}
# [watermark.py:40]               Watermark table now has 19 rows
# [files.py:26]                   Saving file with 19 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241011.json
# [ingestion.py:19]               Processing products_20241012.json
# [files.py:42]                   Reading json file from ./data/products/products_20241012.json with kwargs {}
# [dataframes.py:134]             Processing data for product
# [files.py:59]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:38]                   Reading parquet file from ./final_data/product.parquet
# [files.py:66]                   product file has 18 rows
# [dataframes.py:143]             Found 0 error records for product
# [files.py:22]                   Getting error filename for product
# [dataframes.py:49]              Processing file with 8 records.
# [dataframes.py:82]              Detected 7 old records and 8 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:26]                   Saving file with 26 rows to ./final_data/product.parquet
# [dataframes.py:166]             Processed 8 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 8, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:06.833236'), 'file_date': Timestamp('2024-10-12 00:00:00'), 'file_id': '6d31cbb4-5aac-448c-8887-c6d036b902b8', 'file_name': 'products_20241012.json'}
# [watermark.py:40]               Watermark table now has 20 rows
# [files.py:26]                   Saving file with 20 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241012.json
# [ingestion.py:19]               Processing products_20241013.json
# [files.py:42]                   Reading json file from ./data/products/products_20241013.json with kwargs {}
# [dataframes.py:134]             Processing data for product
# [files.py:59]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:38]                   Reading parquet file from ./final_data/product.parquet
# [files.py:66]                   product file has 26 rows
# [dataframes.py:143]             Found 0 error records for product
# [files.py:22]                   Getting error filename for product
# [dataframes.py:49]              Processing file with 9 records.
# [dataframes.py:82]              Detected 8 old records and 9 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:26]                   Saving file with 35 rows to ./final_data/product.parquet
# [dataframes.py:166]             Processed 9 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 9, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:06.856427'), 'file_date': Timestamp('2024-10-13 00:00:00'), 'file_id': '36b6c27c-3091-4fca-a1d3-5e2881b8b7d2', 'file_name': 'products_20241013.json'}
# [watermark.py:40]               Watermark table now has 21 rows
# [files.py:26]                   Saving file with 21 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241013.json
# [ingestion.py:19]               Processing products_20241014.json
# [files.py:42]                   Reading json file from ./data/products/products_20241014.json with kwargs {}
# [dataframes.py:134]             Processing data for product
# [files.py:59]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:38]                   Reading parquet file from ./final_data/product.parquet
# [files.py:66]                   product file has 35 rows
# [dataframes.py:143]             Found 0 error records for product
# [files.py:22]                   Getting error filename for product
# [dataframes.py:49]              Processing file with 10 records.
# [dataframes.py:82]              Detected 9 old records and 10 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:26]                   Saving file with 45 rows to ./final_data/product.parquet
# [dataframes.py:166]             Processed 10 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 10, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:06.880102'), 'file_date': Timestamp('2024-10-14 00:00:00'), 'file_id': '808be1e3-1d2c-486e-aa5c-5de544c4c6d2', 'file_name': 'products_20241014.json'}
# [watermark.py:40]               Watermark table now has 22 rows
# [files.py:26]                   Saving file with 22 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241014.json
# [ingestion.py:19]               Processing products_20241015.json
# [files.py:42]                   Reading json file from ./data/products/products_20241015.json with kwargs {}
# [dataframes.py:134]             Processing data for product
# [files.py:59]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:38]                   Reading parquet file from ./final_data/product.parquet
# [files.py:66]                   product file has 45 rows
# [dataframes.py:143]             Found 0 error records for product
# [files.py:22]                   Getting error filename for product
# [dataframes.py:49]              Processing file with 11 records.
# [dataframes.py:82]              Detected 10 old records and 11 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:26]                   Saving file with 56 rows to ./final_data/product.parquet
# [dataframes.py:166]             Processed 11 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 11, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:06.903474'), 'file_date': Timestamp('2024-10-15 00:00:00'), 'file_id': 'b788a6cd-e4e8-4e2c-bfd6-0c85f60915b4', 'file_name': 'products_20241015.json'}
# [watermark.py:40]               Watermark table now has 23 rows
# [files.py:26]                   Saving file with 23 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241015.json
# [ingestion.py:19]               Processing products_20241016.json
# [files.py:42]                   Reading json file from ./data/products/products_20241016.json with kwargs {}
# [dataframes.py:134]             Processing data for product
# [files.py:59]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:38]                   Reading parquet file from ./final_data/product.parquet
# [files.py:66]                   product file has 56 rows
# [dataframes.py:143]             Found 0 error records for product
# [files.py:22]                   Getting error filename for product
# [dataframes.py:49]              Processing file with 12 records.
# [dataframes.py:82]              Detected 11 old records and 12 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:26]                   Saving file with 68 rows to ./final_data/product.parquet
# [dataframes.py:166]             Processed 12 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 12, 'error_rows': 0, 'process_time': Timestamp('2024-10-21 21:43:06.972548'), 'file_date': Timestamp('2024-10-16 00:00:00'), 'file_id': '2c3ffa9e-d012-44d6-87ac-7530367cc3c7', 'file_name': 'products_20241016.json'}
# [watermark.py:40]               Watermark table now has 24 rows
# [files.py:26]                   Saving file with 24 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241016.json

# %% [markdown]
# ## Report Generation

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### Customer Growth

# %%
customers = pd.read_parquet('./final_data/customer.parquet')

dates = customers['effective_from'].unique()

data = []
for date in sorted(dates):
    snapshot = customers[(customers['effective_from'] <= date) & (customers['expiry_date'] > date)]
    data.append({'date': date, 'count': len(snapshot)})

df = pd.DataFrame(data)
df.plot(x='date', y='count')
plt.title('Customer Growth')
plt.xlabel('Date')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ### Sales By Membership

# %%
# Sales By Members
customers = pd.read_parquet('./final_data/customer.parquet')

dates = customers['effective_from'].unique()
sales = pd.read_parquet('./final_data/sales.parquet')
merged = sales.merge(customers, on='customer_id', how='outer')
merged = merged[(merged['effective_from_y'] <= merged['sale_date']) & (merged['expiry_date_y'] > merged['sale_date'])]
data = merged.groupby(['sale_date', 'membership_status'])['total_price'].sum().unstack().fillna(0)

data.plot()
plt.title('Sales by Membership Status')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ### Product Sale Breakdown

# %%
# pivot of most popular products over time from members vs non-members

products = pd.read_parquet('./final_data/product.parquet')
customers = pd.read_parquet('./final_data/customer.parquet')
sales = pd.read_parquet('./final_data/sales.parquet')

merged = sales.merge(customers, on='customer_id', how='outer')
merged = merged[(merged['effective_from_y'] <= merged['sale_date']) & (merged['expiry_date_y'] > merged['sale_date'])]
merged_with_products = merged.merge(products, on='product_id', how='left')
data = merged_with_products.groupby(['sale_date', 'membership_status', 'name'])['total_price'].sum().unstack().fillna(0)

data
# Out:
# name                              Camera  External Hard Drive  Headphones  \
# sale_date  membership_status
# 2024-10-09 active                   0.00                 0.00        0.00
#            inactive                 0.00                 0.00        0.00
# 2024-10-10 active                   0.00                 0.00        0.00
#            inactive                 0.00                 0.00        0.00
# 2024-10-11 active                   0.00                 0.00        0.00
#            inactive                 0.00                 0.00        0.00
# 2024-10-12 active                   0.00                 0.00   678205.00
#            inactive                 0.00                 0.00  1285350.00
# 2024-10-13 active             2550283.20                 0.00   683074.00
#            inactive           4763270.88                 0.00  1316854.00
# 2024-10-14 active             2921618.56            215753.46   738180.05
#            inactive           4349880.32            355727.04  1285508.20
# 2024-10-15 active             2540523.60            217081.62   696528.00
#            inactive           4409677.60            344829.24  1112832.00
#
# name                               Laptop     Monitor      Mouse     Printer  \
# sale_date  membership_status
# 2024-10-09 active              8816292.80  1628895.60  234393.60  1587331.20
#            inactive           18353475.84  3694003.92  549964.80  3383962.40
# 2024-10-10 active              6895058.80  1504407.68  206568.72  1303281.44
#            inactive           14974209.60  3291128.64  380302.08  2825822.88
# 2024-10-11 active              6783552.00  1350208.00  197869.44  1320954.00
#            inactive           12210393.60  2550598.40  360835.84  2788466.40
# 2024-10-12 active              6034572.96  1435310.72  191368.32  1295128.08
#            inactive           11031683.52  2590755.84  345384.00  2427647.76
# 2024-10-13 active              4903997.28  1397400.00  173260.80  1460641.60
#            inactive            9626657.04  2472480.00  285880.32  2307418.96
# 2024-10-14 active              4675396.00  1194963.84  145403.04  1348475.68
#            inactive            7816340.00  2063854.08  261631.36  2234844.48
# 2024-10-15 active              4209469.28  1269053.76  178456.08  1227927.36
#            inactive            7140705.44  1908781.68  264039.76  1948119.36
#
# name                              Router  Smartphone  Smartwatch     Tablet
# sale_date  membership_status
# 2024-10-09 active             1550015.04        0.00        0.00       0.00
#            inactive           3152942.24        0.00        0.00       0.00
# 2024-10-10 active             1392053.52        0.00   622643.77       0.00
#            inactive           2513116.32        0.00  1250925.97       0.00
# 2024-10-11 active             1268696.32  3496013.82   570077.20       0.00
#            inactive           2266408.96  5925592.92  1166769.45       0.00
# 2024-10-12 active             1054041.12  3256309.86   620483.85       0.00
#            inactive           1859568.48  6413658.06  1033328.66       0.00
# 2024-10-13 active              952834.24  3059404.32   523596.15       0.00
#            inactive           1750524.00  5815709.76  1120546.35       0.00
# 2024-10-14 active              972127.52  3037824.30   496127.94       0.00
#            inactive           1484253.68  4949214.48   923046.81       0.00
# 2024-10-15 active              812860.48  2910810.36   451376.38  555688.90
#            inactive           1397803.84  5012801.04   811420.75  980727.28

# %%
# 1. The top 10 people who purchased the largest number of products
top_customers = merged.groupby(['customer_id', 'first_name', 'last_name', 'email'])\
                        .agg({'quantity': 'sum'}).reset_index()\
                        .sort_values(by='quantity', ascending=False)\
                        .head(10)
top_customers.rename(columns={'quantity': 'total_items_purchased'}, inplace=True)

top_customers.to_csv('sales_report.csv', index=False)

# %%
# 2. The top 10 people who purchased the largest number of products while being an active member
top_active_customers = merged[merged['membership_status'] == 'active']\
                    .groupby(['customer_id', 'first_name', 'last_name', 'email'])\
                    .agg({'quantity': 'sum'}).reset_index()\
                    .sort_values(by='quantity', ascending=False)\
                    .head(10)
top_active_customers.rename(columns={'quantity': 'total_items_purchased'}, inplace=True)

top_active_customers.to_csv('sales_report_active_member.csv', index=False)
